# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from retrying import retry
from requests.exceptions import RequestException, ConnectTimeout

# Function to fetch data from a page with retry decorator
@retry(wait_exponential_multiplier=1000, wait_exponential_max=10000, stop_max_attempt_number=3, retry_on_exception=lambda exc: isinstance(exc, (ConnectTimeout, RequestException)))

def fetch_page(url):
    response = requests.get(url, timeout=10)
    response.raise_for_status()
    return response

url = "https://maharerait.mahaonline.gov.in/SearchList/Search"
search_data = {
    '__RequestVerificationToken': '-8sf6SeyGSCPB-ZGIlz43EFH7Q5v83OunCAqJdQmP-esfJDKqOZ98hcjqvK_mzO9-t32MbTJm8W_wBRd8HNp5-sSh5dbIID_QNSm1bYZZTM1',
    'Type': 'Agent',
    'AgentName': 'abhi',
    'pageTraverse': '1'
}

# Increase the timeout to a higher value (e.g., 30 seconds)
timeout_value = 30

try:
    response = requests.post(url, data=search_data, timeout=timeout_value)
    response.raise_for_status()
except requests.exceptions.Timeout:
    print("Timeout occurred. The server took too long to respond.")
    exit(1)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
    exit(1)
soup = BeautifulSoup(response.text, 'html.parser')
data = soup.find_all('tr', class_='grid-row')

# Lists to store data
broker_names = []
certificate_numbers = []
criminal_records = []
house_numbers = []
building_names = []
pin_codes = []

# Extract the data from the first page
for item in data:
    broker_name = item.find('td', class_='grid-cell', attrs={'data-name': 'Name'}).text.strip()
    certificate_number = item.find('td', class_='grid-cell', attrs={'data-name': 'CertiNo'}).text.strip()
    
    # Append data to the lists
    broker_names.append(broker_name)
    certificate_numbers.append(certificate_number)

    link = item.find('a')['href']
    full_url = f"https://maharerait.mahaonline.gov.in{link}"
    response_new = requests.get(full_url)
    new_soup = BeautifulSoup(response_new.text, 'html.parser')

    div_house_number = new_soup.find('label', string='House Number')
    if div_house_number:
        house_number = div_house_number.find_next('div').text.strip()
        house_numbers.append(house_number)
    else:
        house_numbers.append("House number not found.")
        
    div_building_name = new_soup.find('label', string='Building Name')
    if div_building_name:
        building_name = div_building_name.find_next('div').text.strip()
        building_names.append(building_name)
    else:
        building_names.append("Building name not found.")
    
    div_pin_code = new_soup.find('label', string='Pin Code')
    if div_pin_code:
        pin_code = div_pin_code.find_next('div').text.strip()
        pin_codes.append(pin_code)
    else:
        pin_codes.append("Pin code not found.")
    
    div_with_label_criminal = new_soup.select_one('label.mandatory[for="PersonalInfoModel_IsCriminal"]')
    if div_with_label_criminal:
        criminal_record = div_with_label_criminal.find_next('div').text.strip()
        criminal_records.append(criminal_record)
    else:
        criminal_records.append("Criminal record not found.")

# Create a DataFrame to store the data from the first page
result_df1 = pd.DataFrame({
    'Broker Name': broker_names,
    'Certificate Number': certificate_numbers,
    'Criminal Record': criminal_records,
    'House Number': house_numbers,
    'Building Name': building_names,
    'Pin Code': pin_codes
})

# Reset the index to start from one
result_df1.index = range(1, len(result_df1) + 1)

# Print the DataFrame for the first page
print(result_df1)

# Function to fetch data from the second page with retry decorator
@retry(wait_exponential_multiplier=1000, wait_exponential_max=10000, stop_max_attempt_number=3)
def fetch_second_page(url):
    response = requests.post(url, data=search_data, timeout=timeout_value)
    response.raise_for_status()
    return response

# Second page data retrieval
# Lists to store data
localities = []
landmarks = []
states = []
divisions = []
districts = []
talukas = []
villages = []

try:
    response = fetch_second_page(url)
except requests.exceptions.Timeout:
    print("Timeout occurred. The server took too long to respond.")
    exit(1)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
    exit(1)

soup = BeautifulSoup(response.text, 'html.parser')
data = soup.find_all('tr', class_='grid-row')

# Iterate through each item (link to individual pages) in data
for item in data:
    link = item.find('a')['href']
    full_url = f"https://maharerait.mahaonline.gov.in{link}"
    
    try:
        response_new = fetch_page(full_url)
        new_soup = BeautifulSoup(response_new.text, 'html.parser')
        rows = new_soup.find_all('div', class_='row')
        locality = None
        landmark = None
        state = None
        division = None
        district = None
        taluka = None
        village = None

        for row in rows:
            labels = row.find_all('label')
            for label in labels:
                if label.get_text(strip=True) == 'Locality':
                    locality = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'Landmark':
                    landmark = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'State/UT':
                    state = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'Division':
                    division = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'District':
                    district = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'Taluka':
                    taluka = label.find_next('div').get_text(strip=True)
                elif label.get_text(strip=True) == 'Village':
                    village = label.find_next('div').get_text(strip=True)  # Corrected variable name
                    
        # Append the extracted data to respective lists
        localities.append(locality)
        landmarks.append(landmark)
        states.append(state)
        divisions.append(division)
        districts.append(district)
        talukas.append(taluka)
        villages.append(village)  # Corrected variable name
        
    except requests.exceptions.RequestException as e:
        print(f"Error accessing page: {full_url}")
        print(e)
        continue  # Skip this page and continue with the next one

# Create a DataFrame to store the data from the second page
result_df2 = pd.DataFrame({
    'Locality': localities,
    'Landmark': landmarks,
    'State/UT': states,
    'Division': divisions,
    'District': districts,
    'Taluka': talukas,
    'Village': villages
})

# Reset the index to start from one
result_df2.index = range(1, len(result_df2) + 1)

# Print the DataFrame for the second page
#print(result_df2)

# Concatenate the data from both pages into a single dataframe
final_result = pd.concat([result_df1, result_df2], axis=1)

# Print the combined DataFrame
print(final_result)
# Out:
#                         Broker Name Certificate Number  \
# 1               Abhishek  Kandalkar       A51800013819
# 2        ABHIMANYU MAROTRAO TAYWADE       A50300006147
# 3          Abhijeet Laxman Pardeshi       A52100005879
# 4          ABHIJIT SANTOSH JOPULKAR       A51600018559
# 5              ABHIJIT RAMDAS BHURE       A51000037945
# 6           ABHISHEK KISHOR BIDAWAT       A51600018797
# 7          Abhijeet Shrikant Mankar       A50100038196
# 8         ABHISHEK SOMNATH BIRAJDAR       A52500031627
# 9              Abhijeet P Manathkar       A51100030603
# 10  ABHIDI REALTY ADVISORS PVT.LTD.       A51900002423
# 11         ABHIJEET BHAURAO GAIKWAD       A51500035292
# 12            ABHIJIT DEORAOJI KALE       A50500021021
# 13                ABHIJIT  MUKERJEE       A15700022618
# 14       ABHIDI RETAIL ADVISORS LLP       A51900002874
# 15           Abhijit Ravasaheb Hude       A52400042585
# 16       ABHILASH CHANDRAKANT AGWAN       A52300043873
# 17             ABHISHEK SUHAS JOSHI       A52100015175
# 18            ABHIJEET DILIP SHINDE       A51600029584
# 19          ABHISHEK SUDHAKAR KAKDE       A50500027951
# 20                    Abhijeet  Roy       A52100015912
# 21           ABHIJEET NAVNEET RUMDE       A99000009517
# 22               ABHISHEK ANIL PURI       A50500030096
# 23           ABHIJIT JAGDISH MUPPID       A52100015844
# 24      Abhishek Harinarayan Badiye       A50500031503
# 25      ABHILASH SURESH RATNAPARKHI       A50500031455
# 26    ABHIJEET BHALCHANDRA LOKAPURE       A53000016753
# 27                   Abhinav  Dixit       A52100016478
# 28           ABHISHEK SURESH KOKATE       A51700013939
# 29       ABHISHEK MILIND KHOBRAGADE       A50800037186
# 30        Abhishek Pradeeprao Patil       A52100017231
# 31               Abhisshek  Jaywant       A51700014665
# 32          ABHIJIT SADASHIV JADHAV       A52100017452
# 33            ABHIJEET RAMESH PANDE       A50500039134
# 34             ABHISHEK ARUN BHUKAN       A52100018332
# 35       ABHILASH SHRIKANT WANKHADE       A50500040676
# 36       Abhishek Chhaganlal Parmar       A51700016165
# 37            Abhijit Keshav Kapase       A52100018315
# 38            ABHIJIT VISHNU JADHAV       A52100018543
# 39      ABHIJIT TARACHAND DUNGARWAL       A52100018452
# 40        ABHIJEET AMBADAS MALGHATE       A50500041624
# 41              ABHILASH  PRAJAPATI       A50500041799
# 42                  Abhishek  Dayal       A52000033283
# 43       ABHIJEET PRABHAKAR MAHAJAN       A50500041705
# 44           Abhilasha  Shrivastava       A52100019365
# 45              Abhishek Nayan Shah       A52100019147
# 46                   ABHISHEK  NAIR       A52100002897
# 47            ABHISHEK  PRIYADARSHI       A52100019615
# 48        ABHISHEK RAKESH MANESHWAR       A50500011904
# 49                  Abhishek  Saini       A52100019851
# 50      ABHINANDAN MURLIDHAR SHARMA       A52000001397
#
#                Criminal Record                               House Number  \
# 1                           No                                        401
# 2                           No                                        B23
# 3                           No                                         10
# 4                           No  VENU SADAN OM NAGAR BEHIND SAATBHAI NAGAR
# 5                           No                                         69
# 6                           No                     OFFICE NO 02 6TH FLOOR
# 7                           No                            Near Water Tank
# 8                           No                                C/O Somnath
# 9                           No                                    1-7-478
# 10  Criminal record not found.                    House number not found.
# 11                          No                                  FLAT NO 4
# 12                          No                                  PLOT NO 8
# 13                          No                                      88/30
# 14  Criminal record not found.                    House number not found.
# 15                          No                                  Kawathala
# 16                          No                               H NO 1 3 472
# 17                          No                                CHITRA 303,
# 18                          No                                 Plot No 64
# 19                          No                                FLAT NO 107
# 20                          No                               Raw house -9
# 21                          No                                        101
# 22                          No                                       FO-5
# 23                          No                                HOUSE NO 30
# 24                          No                                Flat No 303
# 25                          No                                  PLOT NO 1
# 26                          No               22 A JIVBHA NANA JADHAV PARK
# 27                          No                                     D3-702
# 28                          No                                  Shop No 9
# 29                          No                                          -
# 30                          No                                  Flat no 7
# 31                          No                                     C-702,
# 32                          No                                 SHOP NO 22
# 33                          No                      FLAT NO-404 4TH FLOOR
# 34                          No                                SHOP NO 316
# 35                          No                                         96
# 36                          No                                          5
# 37                          No                   Flat no 1105, 11th Floor
# 38                          No                                      A-701
# 39                          No                                 FLAT NO-A1
# 40                          No                C/O MEENA MADHUKAR MALGHATE
# 41                          No                                 PLOT NO 26
# 42                          No                                       1005
# 43                          No                                 PLOT NO 18
# 44                          No                                      G-526
# 45                          No                                        6-7
# 46                          No                                      B/502
# 47                          No                                     A2/211
# 48                          No                        C/O GANGADHAR PACHE
# 49                          No                                      B-804
# 50                          No                                       1701
#
#                                   Building Name Pin Code
# 1                             Vikram Apartments   400049
# 2                                 TAYWADE HOUSE   444603
# 3                              Kapil Apartments   411038
# 4                                     JAIL ROAD   422101
# 5                                  KUNDAN NAGAR   445302
# 6                  SIDDHI POOJA BUSINESS SQUARE   422002
# 7                                 Mahajani Plot   444005
# 8                               Yashawant Nagar   413605
# 9                                      Ashirwad   431602
# 10                           BARODAWALA MANSION   400018
# 11                                KRUSHNA VIHAR   431001
# 12                                            1   440034
# 13                                 MAQBOOL GANJ   226018
# 14                           BARODAWALA MANSION   400018
# 15                                    Kawathali   413519
# 16                                  Mitra Nagar   431122
# 17                                SUVIDHA AMBAR   411041
# 18                                       prince   422222
# 19                              GAURI MEDOWS-II   440037
# 20                              B2 Vandeo Nagar   411033
# 21                                MAHESH SMRUTI   401303
# 22                                SILVER PALACE   440012
# 23                            SAPRAS LINE BAZAR   411003
# 24                                Maxx Sanman B   440034
# 25                                AMRAVATI ROAD   440023
# 26                               NEW WASHI NAKA   416011
# 27                              Ganga Constella   411014
# 28                          Unique Aurum D wing   401107
# 29                                            -   442605
# 30                         Vardha Vihar Society   411041
# 31  Vastu Apts, Krishna Greenland Park compound   400615
# 32                           ADITYA SHAGUN MALL   411021
# 33                         DEVANJALI APPARTMENT   440009
# 34                                   CROSSROADS   411057
# 35                                            -   440022
# 36                                    Neeta CHS   421301
# 37                      Gera Park View, H South   411014
# 38                          CAMELLIA APARTMENTS   411021
# 39                                SAMRAT TOWERS   411043
# 40                                KRISHNA NIWAS   441107
# 41                                 SHANTI NIWAS   440022
# 42                            Rajesh Presidancy   410206
# 43                                MAHAJAN HOUSE   440025
# 44                            Shree Hans Garden   411015
# 45                                 Maya Classic   411040
# 46                               MATRIX ALFA 1,   411014
# 47                              Yellow Blossoms   411036
# 48                         S/O RAKESH MANESHWAR   440013
# 49                          Hill View Apartment   411060
# 50                             BALAJI RESIDENCY   410210
#                                      Locality  \
# 1                                        Juhu
# 2                                 ARJUN NAGAR
# 3                         Paud road, Kothrud,
# 4                                      NASHIK
# 5                                     KELAPUR
# 6                                   SHARANPUR
# 7                               Mahajani Plot
# 8                               Murum (Rural)
# 9                         Near Pawdewadi Naka
# 10                                      WORLI
# 11                             NEW SBH COLONY
# 12                         MANGALDEEP NAGAR 2
# 13                              AMINABAD PARK
# 14                                      WORLI
# 15                                      Deoni
# 16                                       Beed
# 17                                      NARHE
# 18                                 HAL Colony
# 19                                       BESA
# 20                                  Theragaon
# 21                                      VIRAR
# 22                                   DHANTOLI
# 23                                EAST KHADKI
# 24                          Old Harihar Nagar
# 25                                  DATTAWADI
# 26                                   KOLHAPUR
# 27                                    Kharadi
# 28                                   MIRAROAD
# 29                               RAMPURI WARD
# 30                              Vadgao Budruk
# 31                               Kasarwadavli
# 32                  NEAR DSK RANWARA NDA ROAD
# 33                              HANUMAN NAGAR
# 34                                      WAKAD
# 35                                JAITALAROAD
# 36                            Ahilyabai Chowk
# 37                                    Kharadi
# 38                                     PASHAN
# 39                            SUKHSAGAR NAGAR
# 40  RAMKRUSHNA NAGAR, WARD NO 04, SAVNER(MCI)
# 41           DRONACHARY NAGAR, TRIMURTI NAGAR
# 42                                       Ulwe
# 43                                  SOMALWADA
# 44                                    Dhanori
# 45                       Near to Mount Carmel
# 46                                    KHARADI
# 47                                   Ghorpade
# 48                     MANAVTA NAGAR TV TOWER
# 49                                     Pisoli
# 50                                  SECTOR 15
#
#                              Landmark       State/UT    Division  \
# 1                Near Prithvi Theatre    MAHARASHTRA      Konkan
# 2              NEAR BY HANUMAN TEMPLE    MAHARASHTRA    Amravati
# 3                   Opp Vanaz Company    MAHARASHTRA        Pune
# 4                   NEAR ADHAAV CHAWL    MAHARASHTRA      Nashik
# 5                       HERO SHOWROOM    MAHARASHTRA    Amravati
# 6              OPP SONY PAITHANI SADI    MAHARASHTRA      Nashik
# 7                       Mahajani Plot    MAHARASHTRA    Amravati
# 8                              Omerga    MAHARASHTRA  Aurangabad
# 9             Opp.Tirupati Appartment    MAHARASHTRA  Aurangabad
# 10                               None    MAHARASHTRA      Konkan
# 11                         AURANGABAD    MAHARASHTRA  Aurangabad
# 12                 MANEWADA BESA ROAD    MAHARASHTRA      Nagpur
# 13                      AMINABAD PARK  UTTAR PRADESH        None
# 14                               None    MAHARASHTRA      Konkan
# 15                              Deoni    MAHARASHTRA  Aurangabad
# 16                               Beed    MAHARASHTRA  Aurangabad
# 17                              NARHD    MAHARASHTRA        Pune
# 18                  Near Bardan Phata    MAHARASHTRA      Nashik
# 19      BEHIND INDIAN OIL PETROL PUMP    MAHARASHTRA      Nagpur
# 20                      Abhijeet park    MAHARASHTRA        Pune
# 21                         RAM MANDIR    MAHARASHTRA      Konkan
# 22               OPP YASHWANT STADIUM    MAHARASHTRA      Nagpur
# 23         LOKMANYA TILAK HIGH SCHOOL    MAHARASHTRA        Pune
# 24                               Besa    MAHARASHTRA      Nagpur
# 25                             NAGPUR    MAHARASHTRA      Nagpur
# 26                  NR GANPATI MANDIR    MAHARASHTRA        Pune
# 27                   Near Eon IT Park    MAHARASHTRA        Pune
# 28               Near SK Stone Signal    MAHARASHTRA      Konkan
# 29                    Z P HIGH SCHOOL    MAHARASHTRA      Nagpur
# 30       Apoorva Near Santosh Medical    MAHARASHTRA        Pune
# 31                          Hypercity    MAHARASHTRA      Konkan
# 32                         BAVDHAN KH    MAHARASHTRA        Pune
# 33                      NEAR HEDGEWAR    MAHARASHTRA      Nagpur
# 34                      BHUMKAR CHOWK    MAHARASHTRA        Pune
# 35      ELECTRIC POL RANAPRATAP NAGAR    MAHARASHTRA      Nagpur
# 36               Near Annapurna Hotel    MAHARASHTRA      Konkan
# 37                   Near Eon IT Park    MAHARASHTRA        Pune
# 38                             PASHAN    MAHARASHTRA        Pune
# 39               NEAR AMBAMATA MANDIR    MAHARASHTRA        Pune
# 40                    NEAR RAM MANDIR    MAHARASHTRA      Nagpur
# 41           NEAR PURTI ANAAJ BHANDAR    MAHARASHTRA      Nagpur
# 42                   Ulwe Navi Mumbai    MAHARASHTRA      Konkan
# 43                     GANGULI LAYOUT    MAHARASHTRA      Nagpur
# 44                   Opp. Canara bank    MAHARASHTRA        Pune
# 45                        Lulla nagar    MAHARASHTRA        Pune
# 46                            KHARADI    MAHARASHTRA        Pune
# 47                 Bharat petrol pump    MAHARASHTRA        Pune
# 48          NEAR DHANRAJ KIRANA STORE    MAHARASHTRA      Nagpur
# 49  Near Brick School Of Architecture    MAHARASHTRA        Pune
# 50                        NEAR D MART    MAHARASHTRA      Konkan
#
#            District          Taluka                    Village
# 1   Mumbai Suburban         Andheri                    Andheri
# 2          Amravati        Amravati         Amravati (M Corp.)
# 3              Pune          Haveli                    Kothrud
# 4            Nashik          Nashik                Nashik Road
# 5          Yavatmal         Kelapur
# 6            Nashik          Nashik           Nashik (M Corp.)
# 7             Akola           Akola            Akola (M Corp.)
# 8         Osmanabad          Umarga              Murum (Rural)
# 9            Nanded          Nanded
# 10      Mumbai City     Mumbai City                Mumbai City
# 11       Aurangabad      Aurangabad       Aurangabad (M Corp.)
# 12           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 13          Lucknow         Lucknow
# 14      Mumbai City     Mumbai City                Mumbai City
# 15            Latur           Deoni                   Kawthala
# 16             beed             Bid                 Bid (M Cl)
# 17             Pune          Haveli                      NARHE
# 18           Nashik          Nashik                  Govardhan
# 19           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 20             Pune          Mulshi                   Thergaon
# 21          Palghar           Vasai  Vasai-Virar City (M Corp)
# 22           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 23             Pune       Pune City                  Pune (CB)
# 24           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 25           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 26         Kolhapur          Karvir         Kolhapur (M Corp.)
# 27             Pune          Haveli                    KHARADI
# 28            Thane           Thane   Mira-Bhayandar (M Corp.)
# 29       Gadchiroli       Chamorshi                  Chamorshi
# 30             Pune       Pune City             Pune (M Corp.)
# 31            Thane           Thane            Thane (M Corp.)
# 32             Pune          Haveli                Bavdhan Kh.
# 33           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 34             Pune       Pune City             Pune (M Corp.)
# 35           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 36            Thane          Kalyan                     Kalyan
# 37             Pune       Pune City             Pune (M Corp.)
# 38             Pune          Haveli                     Pashan
# 39             Pune       Pune City             Pune (M Corp.)
# 40           Nagpur          Savner              Savner (M Cl)
# 41           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 42          Raigarh          Panvel                      Ulawe
# 43           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 44             Pune          Haveli                    DHANORI
# 45             Pune       Pune City             Pune (M Corp.)
# 46             Pune       Pune City             Pune (M Corp.)
# 47             Pune       Pune City                  Pune (CB)
# 48           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 49             Pune          Haveli                     Pisoli
# 50          Raigarh          Panvel                   Kharghar
#                         Broker Name Certificate Number  \
# 1               Abhishek  Kandalkar       A51800013819
# 2        ABHIMANYU MAROTRAO TAYWADE       A50300006147
# 3          Abhijeet Laxman Pardeshi       A52100005879
# 4          ABHIJIT SANTOSH JOPULKAR       A51600018559
# 5              ABHIJIT RAMDAS BHURE       A51000037945
# 6           ABHISHEK KISHOR BIDAWAT       A51600018797
# 7          Abhijeet Shrikant Mankar       A50100038196
# 8         ABHISHEK SOMNATH BIRAJDAR       A52500031627
# 9              Abhijeet P Manathkar       A51100030603
# 10  ABHIDI REALTY ADVISORS PVT.LTD.       A51900002423
# 11         ABHIJEET BHAURAO GAIKWAD       A51500035292
# 12            ABHIJIT DEORAOJI KALE       A50500021021
# 13                ABHIJIT  MUKERJEE       A15700022618
# 14       ABHIDI RETAIL ADVISORS LLP       A51900002874
# 15           Abhijit Ravasaheb Hude       A52400042585
# 16       ABHILASH CHANDRAKANT AGWAN       A52300043873
# 17             ABHISHEK SUHAS JOSHI       A52100015175
# 18            ABHIJEET DILIP SHINDE       A51600029584
# 19          ABHISHEK SUDHAKAR KAKDE       A50500027951
# 20                    Abhijeet  Roy       A52100015912
# 21           ABHIJEET NAVNEET RUMDE       A99000009517
# 22               ABHISHEK ANIL PURI       A50500030096
# 23           ABHIJIT JAGDISH MUPPID       A52100015844
# 24      Abhishek Harinarayan Badiye       A50500031503
# 25      ABHILASH SURESH RATNAPARKHI       A50500031455
# 26    ABHIJEET BHALCHANDRA LOKAPURE       A53000016753
# 27                   Abhinav  Dixit       A52100016478
# 28           ABHISHEK SURESH KOKATE       A51700013939
# 29       ABHISHEK MILIND KHOBRAGADE       A50800037186
# 30        Abhishek Pradeeprao Patil       A52100017231
# 31               Abhisshek  Jaywant       A51700014665
# 32          ABHIJIT SADASHIV JADHAV       A52100017452
# 33            ABHIJEET RAMESH PANDE       A50500039134
# 34             ABHISHEK ARUN BHUKAN       A52100018332
# 35       ABHILASH SHRIKANT WANKHADE       A50500040676
# 36       Abhishek Chhaganlal Parmar       A51700016165
# 37            Abhijit Keshav Kapase       A52100018315
# 38            ABHIJIT VISHNU JADHAV       A52100018543
# 39      ABHIJIT TARACHAND DUNGARWAL       A52100018452
# 40        ABHIJEET AMBADAS MALGHATE       A50500041624
# 41              ABHILASH  PRAJAPATI       A50500041799
# 42                  Abhishek  Dayal       A52000033283
# 43       ABHIJEET PRABHAKAR MAHAJAN       A50500041705
# 44           Abhilasha  Shrivastava       A52100019365
# 45              Abhishek Nayan Shah       A52100019147
# 46                   ABHISHEK  NAIR       A52100002897
# 47            ABHISHEK  PRIYADARSHI       A52100019615
# 48        ABHISHEK RAKESH MANESHWAR       A50500011904
# 49                  Abhishek  Saini       A52100019851
# 50      ABHINANDAN MURLIDHAR SHARMA       A52000001397
#
#                Criminal Record                               House Number  \
# 1                           No                                        401
# 2                           No                                        B23
# 3                           No                                         10
# 4                           No  VENU SADAN OM NAGAR BEHIND SAATBHAI NAGAR
# 5                           No                                         69
# 6                           No                     OFFICE NO 02 6TH FLOOR
# 7                           No                            Near Water Tank
# 8                           No                                C/O Somnath
# 9                           No                                    1-7-478
# 10  Criminal record not found.                    House number not found.
# 11                          No                                  FLAT NO 4
# 12                          No                                  PLOT NO 8
# 13                          No                                      88/30
# 14  Criminal record not found.                    House number not found.
# 15                          No                                  Kawathala
# 16                          No                               H NO 1 3 472
# 17                          No                                CHITRA 303,
# 18                          No                                 Plot No 64
# 19                          No                                FLAT NO 107
# 20                          No                               Raw house -9
# 21                          No                                        101
# 22                          No                                       FO-5
# 23                          No                                HOUSE NO 30
# 24                          No                                Flat No 303
# 25                          No                                  PLOT NO 1
# 26                          No               22 A JIVBHA NANA JADHAV PARK
# 27                          No                                     D3-702
# 28                          No                                  Shop No 9
# 29                          No                                          -
# 30                          No                                  Flat no 7
# 31                          No                                     C-702,
# 32                          No                                 SHOP NO 22
# 33                          No                      FLAT NO-404 4TH FLOOR
# 34                          No                                SHOP NO 316
# 35                          No                                         96
# 36                          No                                          5
# 37                          No                   Flat no 1105, 11th Floor
# 38                          No                                      A-701
# 39                          No                                 FLAT NO-A1
# 40                          No                C/O MEENA MADHUKAR MALGHATE
# 41                          No                                 PLOT NO 26
# 42                          No                                       1005
# 43                          No                                 PLOT NO 18
# 44                          No                                      G-526
# 45                          No                                        6-7
# 46                          No                                      B/502
# 47                          No                                     A2/211
# 48                          No                        C/O GANGADHAR PACHE
# 49                          No                                      B-804
# 50                          No                                       1701
#
#                                   Building Name Pin Code  \
# 1                             Vikram Apartments   400049
# 2                                 TAYWADE HOUSE   444603
# 3                              Kapil Apartments   411038
# 4                                     JAIL ROAD   422101
# 5                                  KUNDAN NAGAR   445302
# 6                  SIDDHI POOJA BUSINESS SQUARE   422002
# 7                                 Mahajani Plot   444005
# 8                               Yashawant Nagar   413605
# 9                                      Ashirwad   431602
# 10                           BARODAWALA MANSION   400018
# 11                                KRUSHNA VIHAR   431001
# 12                                            1   440034
# 13                                 MAQBOOL GANJ   226018
# 14                           BARODAWALA MANSION   400018
# 15                                    Kawathali   413519
# 16                                  Mitra Nagar   431122
# 17                                SUVIDHA AMBAR   411041
# 18                                       prince   422222
# 19                              GAURI MEDOWS-II   440037
# 20                              B2 Vandeo Nagar   411033
# 21                                MAHESH SMRUTI   401303
# 22                                SILVER PALACE   440012
# 23                            SAPRAS LINE BAZAR   411003
# 24                                Maxx Sanman B   440034
# 25                                AMRAVATI ROAD   440023
# 26                               NEW WASHI NAKA   416011
# 27                              Ganga Constella   411014
# 28                          Unique Aurum D wing   401107
# 29                                            -   442605
# 30                         Vardha Vihar Society   411041
# 31  Vastu Apts, Krishna Greenland Park compound   400615
# 32                           ADITYA SHAGUN MALL   411021
# 33                         DEVANJALI APPARTMENT   440009
# 34                                   CROSSROADS   411057
# 35                                            -   440022
# 36                                    Neeta CHS   421301
# 37                      Gera Park View, H South   411014
# 38                          CAMELLIA APARTMENTS   411021
# 39                                SAMRAT TOWERS   411043
# 40                                KRISHNA NIWAS   441107
# 41                                 SHANTI NIWAS   440022
# 42                            Rajesh Presidancy   410206
# 43                                MAHAJAN HOUSE   440025
# 44                            Shree Hans Garden   411015
# 45                                 Maya Classic   411040
# 46                               MATRIX ALFA 1,   411014
# 47                              Yellow Blossoms   411036
# 48                         S/O RAKESH MANESHWAR   440013
# 49                          Hill View Apartment   411060
# 50                             BALAJI RESIDENCY   410210
#
#                                      Locality  \
# 1                                        Juhu
# 2                                 ARJUN NAGAR
# 3                         Paud road, Kothrud,
# 4                                      NASHIK
# 5                                     KELAPUR
# 6                                   SHARANPUR
# 7                               Mahajani Plot
# 8                               Murum (Rural)
# 9                         Near Pawdewadi Naka
# 10                                      WORLI
# 11                             NEW SBH COLONY
# 12                         MANGALDEEP NAGAR 2
# 13                              AMINABAD PARK
# 14                                      WORLI
# 15                                      Deoni
# 16                                       Beed
# 17                                      NARHE
# 18                                 HAL Colony
# 19                                       BESA
# 20                                  Theragaon
# 21                                      VIRAR
# 22                                   DHANTOLI
# 23                                EAST KHADKI
# 24                          Old Harihar Nagar
# 25                                  DATTAWADI
# 26                                   KOLHAPUR
# 27                                    Kharadi
# 28                                   MIRAROAD
# 29                               RAMPURI WARD
# 30                              Vadgao Budruk
# 31                               Kasarwadavli
# 32                  NEAR DSK RANWARA NDA ROAD
# 33                              HANUMAN NAGAR
# 34                                      WAKAD
# 35                                JAITALAROAD
# 36                            Ahilyabai Chowk
# 37                                    Kharadi
# 38                                     PASHAN
# 39                            SUKHSAGAR NAGAR
# 40  RAMKRUSHNA NAGAR, WARD NO 04, SAVNER(MCI)
# 41           DRONACHARY NAGAR, TRIMURTI NAGAR
# 42                                       Ulwe
# 43                                  SOMALWADA
# 44                                    Dhanori
# 45                       Near to Mount Carmel
# 46                                    KHARADI
# 47                                   Ghorpade
# 48                     MANAVTA NAGAR TV TOWER
# 49                                     Pisoli
# 50                                  SECTOR 15
#
#                              Landmark       State/UT    Division  \
# 1                Near Prithvi Theatre    MAHARASHTRA      Konkan
# 2              NEAR BY HANUMAN TEMPLE    MAHARASHTRA    Amravati
# 3                   Opp Vanaz Company    MAHARASHTRA        Pune
# 4                   NEAR ADHAAV CHAWL    MAHARASHTRA      Nashik
# 5                       HERO SHOWROOM    MAHARASHTRA    Amravati
# 6              OPP SONY PAITHANI SADI    MAHARASHTRA      Nashik
# 7                       Mahajani Plot    MAHARASHTRA    Amravati
# 8                              Omerga    MAHARASHTRA  Aurangabad
# 9             Opp.Tirupati Appartment    MAHARASHTRA  Aurangabad
# 10                               None    MAHARASHTRA      Konkan
# 11                         AURANGABAD    MAHARASHTRA  Aurangabad
# 12                 MANEWADA BESA ROAD    MAHARASHTRA      Nagpur
# 13                      AMINABAD PARK  UTTAR PRADESH        None
# 14                               None    MAHARASHTRA      Konkan
# 15                              Deoni    MAHARASHTRA  Aurangabad
# 16                               Beed    MAHARASHTRA  Aurangabad
# 17                              NARHD    MAHARASHTRA        Pune
# 18                  Near Bardan Phata    MAHARASHTRA      Nashik
# 19      BEHIND INDIAN OIL PETROL PUMP    MAHARASHTRA      Nagpur
# 20                      Abhijeet park    MAHARASHTRA        Pune
# 21                         RAM MANDIR    MAHARASHTRA      Konkan
# 22               OPP YASHWANT STADIUM    MAHARASHTRA      Nagpur
# 23         LOKMANYA TILAK HIGH SCHOOL    MAHARASHTRA        Pune
# 24                               Besa    MAHARASHTRA      Nagpur
# 25                             NAGPUR    MAHARASHTRA      Nagpur
# 26                  NR GANPATI MANDIR    MAHARASHTRA        Pune
# 27                   Near Eon IT Park    MAHARASHTRA        Pune
# 28               Near SK Stone Signal    MAHARASHTRA      Konkan
# 29                    Z P HIGH SCHOOL    MAHARASHTRA      Nagpur
# 30       Apoorva Near Santosh Medical    MAHARASHTRA        Pune
# 31                          Hypercity    MAHARASHTRA      Konkan
# 32                         BAVDHAN KH    MAHARASHTRA        Pune
# 33                      NEAR HEDGEWAR    MAHARASHTRA      Nagpur
# 34                      BHUMKAR CHOWK    MAHARASHTRA        Pune
# 35      ELECTRIC POL RANAPRATAP NAGAR    MAHARASHTRA      Nagpur
# 36               Near Annapurna Hotel    MAHARASHTRA      Konkan
# 37                   Near Eon IT Park    MAHARASHTRA        Pune
# 38                             PASHAN    MAHARASHTRA        Pune
# 39               NEAR AMBAMATA MANDIR    MAHARASHTRA        Pune
# 40                    NEAR RAM MANDIR    MAHARASHTRA      Nagpur
# 41           NEAR PURTI ANAAJ BHANDAR    MAHARASHTRA      Nagpur
# 42                   Ulwe Navi Mumbai    MAHARASHTRA      Konkan
# 43                     GANGULI LAYOUT    MAHARASHTRA      Nagpur
# 44                   Opp. Canara bank    MAHARASHTRA        Pune
# 45                        Lulla nagar    MAHARASHTRA        Pune
# 46                            KHARADI    MAHARASHTRA        Pune
# 47                 Bharat petrol pump    MAHARASHTRA        Pune
# 48          NEAR DHANRAJ KIRANA STORE    MAHARASHTRA      Nagpur
# 49  Near Brick School Of Architecture    MAHARASHTRA        Pune
# 50                        NEAR D MART    MAHARASHTRA      Konkan
#
#            District          Taluka                    Village
# 1   Mumbai Suburban         Andheri                    Andheri
# 2          Amravati        Amravati         Amravati (M Corp.)
# 3              Pune          Haveli                    Kothrud
# 4            Nashik          Nashik                Nashik Road
# 5          Yavatmal         Kelapur
# 6            Nashik          Nashik           Nashik (M Corp.)
# 7             Akola           Akola            Akola (M Corp.)
# 8         Osmanabad          Umarga              Murum (Rural)
# 9            Nanded          Nanded
# 10      Mumbai City     Mumbai City                Mumbai City
# 11       Aurangabad      Aurangabad       Aurangabad (M Corp.)
# 12           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 13          Lucknow         Lucknow
# 14      Mumbai City     Mumbai City                Mumbai City
# 15            Latur           Deoni                   Kawthala
# 16             beed             Bid                 Bid (M Cl)
# 17             Pune          Haveli                      NARHE
# 18           Nashik          Nashik                  Govardhan
# 19           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 20             Pune          Mulshi                   Thergaon
# 21          Palghar           Vasai  Vasai-Virar City (M Corp)
# 22           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 23             Pune       Pune City                  Pune (CB)
# 24           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 25           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 26         Kolhapur          Karvir         Kolhapur (M Corp.)
# 27             Pune          Haveli                    KHARADI
# 28            Thane           Thane   Mira-Bhayandar (M Corp.)
# 29       Gadchiroli       Chamorshi                  Chamorshi
# 30             Pune       Pune City             Pune (M Corp.)
# 31            Thane           Thane            Thane (M Corp.)
# 32             Pune          Haveli                Bavdhan Kh.
# 33           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 34             Pune       Pune City             Pune (M Corp.)
# 35           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 36            Thane          Kalyan                     Kalyan
# 37             Pune       Pune City             Pune (M Corp.)
# 38             Pune          Haveli                     Pashan
# 39             Pune       Pune City             Pune (M Corp.)
# 40           Nagpur          Savner              Savner (M Cl)
# 41           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 42          Raigarh          Panvel                      Ulawe
# 43           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 44             Pune          Haveli                    DHANORI
# 45             Pune       Pune City             Pune (M Corp.)
# 46             Pune       Pune City             Pune (M Corp.)
# 47             Pune       Pune City                  Pune (CB)
# 48           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 49             Pune          Haveli                     Pisoli
# 50          Raigarh          Panvel                   Kharghar

# %%
final_result
# Out:
#                         Broker Name Certificate Number  \
# 1               Abhishek  Kandalkar       A51800013819
# 2        ABHIMANYU MAROTRAO TAYWADE       A50300006147
# 3          Abhijeet Laxman Pardeshi       A52100005879
# 4          ABHIJIT SANTOSH JOPULKAR       A51600018559
# 5              ABHIJIT RAMDAS BHURE       A51000037945
# 6           ABHISHEK KISHOR BIDAWAT       A51600018797
# 7          Abhijeet Shrikant Mankar       A50100038196
# 8         ABHISHEK SOMNATH BIRAJDAR       A52500031627
# 9              Abhijeet P Manathkar       A51100030603
# 10  ABHIDI REALTY ADVISORS PVT.LTD.       A51900002423
# 11         ABHIJEET BHAURAO GAIKWAD       A51500035292
# 12            ABHIJIT DEORAOJI KALE       A50500021021
# 13                ABHIJIT  MUKERJEE       A15700022618
# 14       ABHIDI RETAIL ADVISORS LLP       A51900002874
# 15           Abhijit Ravasaheb Hude       A52400042585
# 16       ABHILASH CHANDRAKANT AGWAN       A52300043873
# 17             ABHISHEK SUHAS JOSHI       A52100015175
# 18            ABHIJEET DILIP SHINDE       A51600029584
# 19          ABHISHEK SUDHAKAR KAKDE       A50500027951
# 20                    Abhijeet  Roy       A52100015912
# 21           ABHIJEET NAVNEET RUMDE       A99000009517
# 22               ABHISHEK ANIL PURI       A50500030096
# 23           ABHIJIT JAGDISH MUPPID       A52100015844
# 24      Abhishek Harinarayan Badiye       A50500031503
# 25      ABHILASH SURESH RATNAPARKHI       A50500031455
# 26    ABHIJEET BHALCHANDRA LOKAPURE       A53000016753
# 27                   Abhinav  Dixit       A52100016478
# 28           ABHISHEK SURESH KOKATE       A51700013939
# 29       ABHISHEK MILIND KHOBRAGADE       A50800037186
# 30        Abhishek Pradeeprao Patil       A52100017231
# 31               Abhisshek  Jaywant       A51700014665
# 32          ABHIJIT SADASHIV JADHAV       A52100017452
# 33            ABHIJEET RAMESH PANDE       A50500039134
# 34             ABHISHEK ARUN BHUKAN       A52100018332
# 35       ABHILASH SHRIKANT WANKHADE       A50500040676
# 36       Abhishek Chhaganlal Parmar       A51700016165
# 37            Abhijit Keshav Kapase       A52100018315
# 38            ABHIJIT VISHNU JADHAV       A52100018543
# 39      ABHIJIT TARACHAND DUNGARWAL       A52100018452
# 40        ABHIJEET AMBADAS MALGHATE       A50500041624
# 41              ABHILASH  PRAJAPATI       A50500041799
# 42                  Abhishek  Dayal       A52000033283
# 43       ABHIJEET PRABHAKAR MAHAJAN       A50500041705
# 44           Abhilasha  Shrivastava       A52100019365
# 45              Abhishek Nayan Shah       A52100019147
# 46                   ABHISHEK  NAIR       A52100002897
# 47            ABHISHEK  PRIYADARSHI       A52100019615
# 48        ABHISHEK RAKESH MANESHWAR       A50500011904
# 49                  Abhishek  Saini       A52100019851
# 50      ABHINANDAN MURLIDHAR SHARMA       A52000001397
#
#                Criminal Record                               House Number  \
# 1                           No                                        401
# 2                           No                                        B23
# 3                           No                                         10
# 4                           No  VENU SADAN OM NAGAR BEHIND SAATBHAI NAGAR
# 5                           No                                         69
# 6                           No                     OFFICE NO 02 6TH FLOOR
# 7                           No                            Near Water Tank
# 8                           No                                C/O Somnath
# 9                           No                                    1-7-478
# 10  Criminal record not found.                    House number not found.
# 11                          No                                  FLAT NO 4
# 12                          No                                  PLOT NO 8
# 13                          No                                      88/30
# 14  Criminal record not found.                    House number not found.
# 15                          No                                  Kawathala
# 16                          No                               H NO 1 3 472
# 17                          No                                CHITRA 303,
# 18                          No                                 Plot No 64
# 19                          No                                FLAT NO 107
# 20                          No                               Raw house -9
# 21                          No                                        101
# 22                          No                                       FO-5
# 23                          No                                HOUSE NO 30
# 24                          No                                Flat No 303
# 25                          No                                  PLOT NO 1
# 26                          No               22 A JIVBHA NANA JADHAV PARK
# 27                          No                                     D3-702
# 28                          No                                  Shop No 9
# 29                          No                                          -
# 30                          No                                  Flat no 7
# 31                          No                                     C-702,
# 32                          No                                 SHOP NO 22
# 33                          No                      FLAT NO-404 4TH FLOOR
# 34                          No                                SHOP NO 316
# 35                          No                                         96
# 36                          No                                          5
# 37                          No                   Flat no 1105, 11th Floor
# 38                          No                                      A-701
# 39                          No                                 FLAT NO-A1
# 40                          No                C/O MEENA MADHUKAR MALGHATE
# 41                          No                                 PLOT NO 26
# 42                          No                                       1005
# 43                          No                                 PLOT NO 18
# 44                          No                                      G-526
# 45                          No                                        6-7
# 46                          No                                      B/502
# 47                          No                                     A2/211
# 48                          No                        C/O GANGADHAR PACHE
# 49                          No                                      B-804
# 50                          No                                       1701
#
#                                   Building Name Pin Code  \
# 1                             Vikram Apartments   400049
# 2                                 TAYWADE HOUSE   444603
# 3                              Kapil Apartments   411038
# 4                                     JAIL ROAD   422101
# 5                                  KUNDAN NAGAR   445302
# 6                  SIDDHI POOJA BUSINESS SQUARE   422002
# 7                                 Mahajani Plot   444005
# 8                               Yashawant Nagar   413605
# 9                                      Ashirwad   431602
# 10                           BARODAWALA MANSION   400018
# 11                                KRUSHNA VIHAR   431001
# 12                                            1   440034
# 13                                 MAQBOOL GANJ   226018
# 14                           BARODAWALA MANSION   400018
# 15                                    Kawathali   413519
# 16                                  Mitra Nagar   431122
# 17                                SUVIDHA AMBAR   411041
# 18                                       prince   422222
# 19                              GAURI MEDOWS-II   440037
# 20                              B2 Vandeo Nagar   411033
# 21                                MAHESH SMRUTI   401303
# 22                                SILVER PALACE   440012
# 23                            SAPRAS LINE BAZAR   411003
# 24                                Maxx Sanman B   440034
# 25                                AMRAVATI ROAD   440023
# 26                               NEW WASHI NAKA   416011
# 27                              Ganga Constella   411014
# 28                          Unique Aurum D wing   401107
# 29                                            -   442605
# 30                         Vardha Vihar Society   411041
# 31  Vastu Apts, Krishna Greenland Park compound   400615
# 32                           ADITYA SHAGUN MALL   411021
# 33                         DEVANJALI APPARTMENT   440009
# 34                                   CROSSROADS   411057
# 35                                            -   440022
# 36                                    Neeta CHS   421301
# 37                      Gera Park View, H South   411014
# 38                          CAMELLIA APARTMENTS   411021
# 39                                SAMRAT TOWERS   411043
# 40                                KRISHNA NIWAS   441107
# 41                                 SHANTI NIWAS   440022
# 42                            Rajesh Presidancy   410206
# 43                                MAHAJAN HOUSE   440025
# 44                            Shree Hans Garden   411015
# 45                                 Maya Classic   411040
# 46                               MATRIX ALFA 1,   411014
# 47                              Yellow Blossoms   411036
# 48                         S/O RAKESH MANESHWAR   440013
# 49                          Hill View Apartment   411060
# 50                             BALAJI RESIDENCY   410210
#
#                                      Locality  \
# 1                                        Juhu
# 2                                 ARJUN NAGAR
# 3                         Paud road, Kothrud,
# 4                                      NASHIK
# 5                                     KELAPUR
# 6                                   SHARANPUR
# 7                               Mahajani Plot
# 8                               Murum (Rural)
# 9                         Near Pawdewadi Naka
# 10                                      WORLI
# 11                             NEW SBH COLONY
# 12                         MANGALDEEP NAGAR 2
# 13                              AMINABAD PARK
# 14                                      WORLI
# 15                                      Deoni
# 16                                       Beed
# 17                                      NARHE
# 18                                 HAL Colony
# 19                                       BESA
# 20                                  Theragaon
# 21                                      VIRAR
# 22                                   DHANTOLI
# 23                                EAST KHADKI
# 24                          Old Harihar Nagar
# 25                                  DATTAWADI
# 26                                   KOLHAPUR
# 27                                    Kharadi
# 28                                   MIRAROAD
# 29                               RAMPURI WARD
# 30                              Vadgao Budruk
# 31                               Kasarwadavli
# 32                  NEAR DSK RANWARA NDA ROAD
# 33                              HANUMAN NAGAR
# 34                                      WAKAD
# 35                                JAITALAROAD
# 36                            Ahilyabai Chowk
# 37                                    Kharadi
# 38                                     PASHAN
# 39                            SUKHSAGAR NAGAR
# 40  RAMKRUSHNA NAGAR, WARD NO 04, SAVNER(MCI)
# 41           DRONACHARY NAGAR, TRIMURTI NAGAR
# 42                                       Ulwe
# 43                                  SOMALWADA
# 44                                    Dhanori
# 45                       Near to Mount Carmel
# 46                                    KHARADI
# 47                                   Ghorpade
# 48                     MANAVTA NAGAR TV TOWER
# 49                                     Pisoli
# 50                                  SECTOR 15
#
#                              Landmark       State/UT    Division  \
# 1                Near Prithvi Theatre    MAHARASHTRA      Konkan
# 2              NEAR BY HANUMAN TEMPLE    MAHARASHTRA    Amravati
# 3                   Opp Vanaz Company    MAHARASHTRA        Pune
# 4                   NEAR ADHAAV CHAWL    MAHARASHTRA      Nashik
# 5                       HERO SHOWROOM    MAHARASHTRA    Amravati
# 6              OPP SONY PAITHANI SADI    MAHARASHTRA      Nashik
# 7                       Mahajani Plot    MAHARASHTRA    Amravati
# 8                              Omerga    MAHARASHTRA  Aurangabad
# 9             Opp.Tirupati Appartment    MAHARASHTRA  Aurangabad
# 10                               None    MAHARASHTRA      Konkan
# 11                         AURANGABAD    MAHARASHTRA  Aurangabad
# 12                 MANEWADA BESA ROAD    MAHARASHTRA      Nagpur
# 13                      AMINABAD PARK  UTTAR PRADESH        None
# 14                               None    MAHARASHTRA      Konkan
# 15                              Deoni    MAHARASHTRA  Aurangabad
# 16                               Beed    MAHARASHTRA  Aurangabad
# 17                              NARHD    MAHARASHTRA        Pune
# 18                  Near Bardan Phata    MAHARASHTRA      Nashik
# 19      BEHIND INDIAN OIL PETROL PUMP    MAHARASHTRA      Nagpur
# 20                      Abhijeet park    MAHARASHTRA        Pune
# 21                         RAM MANDIR    MAHARASHTRA      Konkan
# 22               OPP YASHWANT STADIUM    MAHARASHTRA      Nagpur
# 23         LOKMANYA TILAK HIGH SCHOOL    MAHARASHTRA        Pune
# 24                               Besa    MAHARASHTRA      Nagpur
# 25                             NAGPUR    MAHARASHTRA      Nagpur
# 26                  NR GANPATI MANDIR    MAHARASHTRA        Pune
# 27                   Near Eon IT Park    MAHARASHTRA        Pune
# 28               Near SK Stone Signal    MAHARASHTRA      Konkan
# 29                    Z P HIGH SCHOOL    MAHARASHTRA      Nagpur
# 30       Apoorva Near Santosh Medical    MAHARASHTRA        Pune
# 31                          Hypercity    MAHARASHTRA      Konkan
# 32                         BAVDHAN KH    MAHARASHTRA        Pune
# 33                      NEAR HEDGEWAR    MAHARASHTRA      Nagpur
# 34                      BHUMKAR CHOWK    MAHARASHTRA        Pune
# 35      ELECTRIC POL RANAPRATAP NAGAR    MAHARASHTRA      Nagpur
# 36               Near Annapurna Hotel    MAHARASHTRA      Konkan
# 37                   Near Eon IT Park    MAHARASHTRA        Pune
# 38                             PASHAN    MAHARASHTRA        Pune
# 39               NEAR AMBAMATA MANDIR    MAHARASHTRA        Pune
# 40                    NEAR RAM MANDIR    MAHARASHTRA      Nagpur
# 41           NEAR PURTI ANAAJ BHANDAR    MAHARASHTRA      Nagpur
# 42                   Ulwe Navi Mumbai    MAHARASHTRA      Konkan
# 43                     GANGULI LAYOUT    MAHARASHTRA      Nagpur
# 44                   Opp. Canara bank    MAHARASHTRA        Pune
# 45                        Lulla nagar    MAHARASHTRA        Pune
# 46                            KHARADI    MAHARASHTRA        Pune
# 47                 Bharat petrol pump    MAHARASHTRA        Pune
# 48          NEAR DHANRAJ KIRANA STORE    MAHARASHTRA      Nagpur
# 49  Near Brick School Of Architecture    MAHARASHTRA        Pune
# 50                        NEAR D MART    MAHARASHTRA      Konkan
#
#            District          Taluka                    Village
# 1   Mumbai Suburban         Andheri                    Andheri
# 2          Amravati        Amravati         Amravati (M Corp.)
# 3              Pune          Haveli                    Kothrud
# 4            Nashik          Nashik                Nashik Road
# 5          Yavatmal         Kelapur
# 6            Nashik          Nashik           Nashik (M Corp.)
# 7             Akola           Akola            Akola (M Corp.)
# 8         Osmanabad          Umarga              Murum (Rural)
# 9            Nanded          Nanded
# 10      Mumbai City     Mumbai City                Mumbai City
# 11       Aurangabad      Aurangabad       Aurangabad (M Corp.)
# 12           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 13          Lucknow         Lucknow
# 14      Mumbai City     Mumbai City                Mumbai City
# 15            Latur           Deoni                   Kawthala
# 16             beed             Bid                 Bid (M Cl)
# 17             Pune          Haveli                      NARHE
# 18           Nashik          Nashik                  Govardhan
# 19           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 20             Pune          Mulshi                   Thergaon
# 21          Palghar           Vasai  Vasai-Virar City (M Corp)
# 22           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 23             Pune       Pune City                  Pune (CB)
# 24           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 25           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 26         Kolhapur          Karvir         Kolhapur (M Corp.)
# 27             Pune          Haveli                    KHARADI
# 28            Thane           Thane   Mira-Bhayandar (M Corp.)
# 29       Gadchiroli       Chamorshi                  Chamorshi
# 30             Pune       Pune City             Pune (M Corp.)
# 31            Thane           Thane            Thane (M Corp.)
# 32             Pune          Haveli                Bavdhan Kh.
# 33           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 34             Pune       Pune City             Pune (M Corp.)
# 35           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 36            Thane          Kalyan                     Kalyan
# 37             Pune       Pune City             Pune (M Corp.)
# 38             Pune          Haveli                     Pashan
# 39             Pune       Pune City             Pune (M Corp.)
# 40           Nagpur          Savner              Savner (M Cl)
# 41           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 42          Raigarh          Panvel                      Ulawe
# 43           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 44             Pune          Haveli                    DHANORI
# 45             Pune       Pune City             Pune (M Corp.)
# 46             Pune       Pune City             Pune (M Corp.)
# 47             Pune       Pune City                  Pune (CB)
# 48           Nagpur  Nagpur (Urban)           Nagpur (M Corp.)
# 49             Pune          Haveli                     Pisoli
# 50          Raigarh          Panvel                   Kharghar

# %%
file_path = 'C:\\Users\\abhic\\OneDrive\\Desktop\\New foder\\project\\1project.csv'
final_result.to_csv(file_path, index=False)
